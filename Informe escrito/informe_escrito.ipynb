# %% [markdown]
# ## Introducción

# %% [markdown]
# El presente proyecto se enfoca en el desarrollo de una plataforma web que permite a los usuarios realizar operaciones de trading directamente desde su broker, integrando un valor agregado significativo: la capacidad de utilizar modelos de predicción de precios basados en diferentes estrategias de trading diario. La importancia de este proyecto radica en su capacidad para brindar a los usuarios una ventaja competitiva en el mercado financiero, al permitirles tomar decisiones de inversión informadas y respaldadas por algoritmos avanzados de predicción. Este proyecto es altamente relevante en el campo de la ciencia de datos, ya que combina técnicas de machine learning, modelado predictivo y la integración de APIs para crear una solución práctica que puede transformar la experiencia de trading.
#
# En el mundo del trading financiero, la toma de decisiones basada en datos es esencial para obtener resultados un poco más reales, porque nada se puede asegurar en este mundo. Sin embargo, los operadores a menudo enfrentan dificultades al intentar aprovechar las herramientas predictivas avanzadas, ya sea por la complejidad técnica de su implementación o por la falta de acceso a plataformas que ofrezcan modelos predictivos integrados. La volatilidad y la naturaleza impredecible del mercado requieren de soluciones que puedan procesar grandes volúmenes de datos en tiempo real y ofrecer proyecciones precisas para apoyar las decisiones de trading diarias.
#
# Otro de nuestros motivos principales es aprender a crear una línea de trabajo para poner en producción un modelo que se mejore constantemente haciendo uso de la disciplina de MLOps.

# %% [markdown]
# ## Antecedentes

# %% [markdown]
# Nos basamos en los últimos años cómo el uso de inteligencia artificial y análisis predictivo ha ganado gran relevancia en el ámbito financiero, especialmente en el trading de acciones. Investigaciones previas han demostrado que los modelos de predicción basados en machine learning, como regresiones lineales, pueden ofrecer proyecciones más precisas que los enfoques tradicionales. Sin embargo, muchas plataformas actuales limitan el acceso a estas tecnologías o requieren conocimientos técnicos avanzados para implementarlas.
#
# La predicción de precios de acciones es algo que ha sido un problema relevante durante varios años y aunque mucha gente piense que no se puede nosotros creemos que podemos hacer un modelo para reducir la aleatoriedad de este fenómeno y tomar decisiones más acertadas, con la información que tenemos a nuestro alcance.
#
# En diferentes proyectos y antecedentes se han utilizado modelos de aprendizaje automático como el Random Forest y la Regresión Lineal para predecir el precio de las acciones de empresas tecnológicas, incluyendo Google y Amazon. Sus resultados mostraron que, si bien los modelos eran capaces de predecir con cierta precisión los movimientos a corto plazo, las fluctuaciones repentinas en el mercado afectaban la estabilidad de las predicciones. También se observó que factores externos como los reportes trimestrales y cambios en la dirección de las empresas tenían un gran impacto en los precios de las acciones. Nuestro proyecto busca profundizar en el análisis de estas tres grandes compañías tecnológicas: Google, Amazon y Apple. Hasta ahora, nuestros resultados preliminares sugieren ciertos patrones en la volatilidad de las acciones de Amazon y Apple tras lanzamientos de productos importantes. Aunque aún no hemos implementado un modelo predictivo completo, nos planteamos utilizar estrategias que combinen enfoques de análisis técnico con modelos de series temporales, como el ARIMA

# %% [markdown]
# ## Objetivos

# %% [markdown]
# * Objetivo General:
#
#
# Desarrollar una plataforma web que permita a los usuarios realizar operaciones de trading a través de su broker, integrando modelos de predicción de precios basados en diferentes estrategias, para optimizar la toma de decisiones en su actividad diaria de trading. También esto es importante no solo hacer la parte del modelado sino también la parte de llevarlo a producción.
#
# * Objetivos Específicos:
#
#
# Crear una API personalizada: Desarrollar una API que permita almacenar y gestionar los datos de manera eficiente, utilizando bases de datos tabulares o NoSQL/documentales.
#
#
# Seleccionar y entrenar modelos predictivos: Identificar y entrenar modelos de machine learning adecuados para la predicción de precios, limitando los tickers y optimizando las estrategias utilizadas.
#
#
# Integrar la API con la API del broker: Desarrollar la funcionalidad para que la API de nuestra plataforma se conecte y sincronice con la API del broker, permitiendo la ejecución de operaciones de trading automatizadas.
#
#
# Desplegar la plataforma: Contenerizar la solución y desplegar la plataforma en la nube, garantizando la accesibilidad, escalabilidad y seguridad del sistema.

# %% [markdown]
# ## Planteamiento del problema

# %% [markdown]
# El problema radica en que muchas plataformas de trading actuales no proporcionan a los usuarios herramientas predictivas lo suficientemente accesibles o personalizables para mejorar sus estrategias. Además, existe una desconexión entre los datos históricos, las predicciones de mercado y las operaciones ejecutadas a través de brokers, lo que limita la capacidad de los traders para optimizar sus decisiones y maximizar sus rendimientos.
#
# Mediante el uso de técnicas de ciencia de datos, específicamente modelos de machine learning aplicados a la predicción de precios, es posible desarrollar una solución que integre de manera eficiente estas herramientas dentro de una plataforma accesible para los usuarios. Al implementar modelos predictivos personalizados y conectar de manera fluida la plataforma con APIs de brokers, se puede resolver este problema, proporcionando a los usuarios una experiencia de trading optimizada y basada en datos, sin necesidad de conocimientos técnicos avanzados.
#
# Con este enfoque, se busca no solo simplificar el acceso a la tecnología predictiva, sino también mejorar la toma de decisiones en tiempo real, reduciendo los riesgos asociados al trading y potenciando el rendimiento de las operaciones

# %% [markdown]
# ## Desarrollo de la solución

# %% [markdown]
# Carga y Visualización Inicial de los Datos: El primer paso consiste en obtener los datos históricos de las acciones de Amazon utilizando la API de Yahoo Finance. Se descargaron datos con un intervalo de 15 minutos para un periodo de 10 días, lo que proporciona una buena granularidad para el análisis.

# %% [markdown]
# ## Análisis de Amazon

# %%
import yfinance as yf
from datetime import date, timedelta

# Test dates
dataF = yf.download('AMZN', start='2020-01-01', end='2024-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dataF.head(10)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  93.750000  94.900497  93.207497  94.900497  94.900497  80580000
# 2020-01-03  93.224998  94.309998  93.224998  93.748497  93.748497  75288000
# 2020-01-06  93.000000  95.184502  93.000000  95.143997  95.143997  81236000
# 2020-01-07  95.224998  95.694504  94.601997  95.343002  95.343002  80898000
# 2020-01-08  94.902000  95.550003  94.321999  94.598503  94.598503  70160000
# 2020-01-09  95.494499  95.890999  94.790001  95.052498  95.052498  63346000
# 2020-01-10  95.268501  95.347000  94.000000  94.157997  94.157997  57074000
# 2020-01-13  94.565498  94.900002  94.040001  94.565002  94.565002  55616000
# 2020-01-14  94.293999  94.355499  92.927498  93.472000  93.472000  68818000
# 2020-01-15  93.612503  93.943001  92.754501  93.100998  93.100998  57932000

# %% [markdown]
# Los datos incluyen las siguientes columnas:
#
# Open: Precio de apertura de la acción.
#
# High: Precio máximo alcanzado durante el intervalo.
#
# Low: Precio mínimo alcanzado durante el intervalo.
#
# Close: Precio de cierre de la acción.
#
# Volume: Número de acciones negociadas.

# %%
dataF.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1006.000000  1006.000000  1006.000000  1006.000000  1006.000000
# mean    137.255245   139.034453   135.376526   137.216247   137.216247
# std      27.576463    27.607319    27.413947    27.468805    27.468805
# min      82.075500    83.480003    81.301498    81.820000    81.820000
# 25%     113.835001   116.115000   112.434999   114.309002   114.309002
# 50%     140.830254   143.375000   138.939751   140.585007   140.585007
# 75%     161.148872   162.888756   159.206749   161.190620   161.190620
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  1.006000e+03
# mean   7.537906e+07
# std    3.382767e+07
# min    2.237840e+07
# 25%    5.278502e+07
# 50%    6.577000e+07
# 75%    8.729165e+07
# max    3.113460e+08

# %%
dataF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 130 entries, 2024-09-03 09:30:00 to 2024-09-09 15:45:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       130 non-null    float64
#  1   High       130 non-null    float64
#  2   Low        130 non-null    float64
#  3   Close      130 non-null    float64
#  4   Adj Close  130 non-null    float64
#  5   Volume     130 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 7.1 KB

# %%
## Visualización de los datos:

import matplotlib.pyplot as plt

# Gráfico de la evolución del precio de cierre
plt.figure(figsize=(10, 6))
plt.plot(dataF['Close'], label='Precio de Cierre')
plt.title('Evolución del Precio de Cierre de Amazon')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre (USD)')
plt.legend()
plt.show()

# %%
# Gráfico del volumen negociado
plt.figure(figsize=(10, 6))
plt.bar(dataF.index, dataF['Volume'], label='Volumen Negociado')
plt.title('Volumen Negociado de Amazon')
plt.xlabel('Fecha')
plt.ylabel('Volumen')
plt.show()

# %%
## cálculo de medias móviles
dataF['SMA_50'] = dataF['Close'].rolling(window=50).mean()

# Gráfico de las medias móviles
plt.figure(figsize=(10, 6))
plt.plot(dataF['Close'], label='Precio de Cierre')
plt.plot(dataF['SMA_50'], label='Media Móvil 50 Periodos', linestyle='--')
plt.title('Tendencias con Medias Móviles')
plt.xlabel('Fecha')
plt.ylabel('Precio (USD)')
plt.legend()
plt.show()

# %% [markdown]
# ### Explicación:
#
# Precio de Cierre (línea azul):
#
# La línea azul representa el precio de cierre de las acciones de Amazon en intervalos de 15 minutos. Podemos observar la volatilidad del mercado, con subidas y bajadas bruscas en este periodo de tiempo.
# En la primera parte de la gráfica, el precio muestra una tendencia ascendente, pero luego comienza a fluctuar más drásticamente con caídas pronunciadas, especialmente hacia el final de los días representados.
#
#
# Media Móvil de 50 Periodos (línea naranja discontinua):
#
# La media móvil de 50 periodos es una medida suavizada que promedia los precios de los últimos 50 periodos. Su función es destacar la tendencia a corto plazo de la serie de precios, eliminando el ruido de las fluctuaciones momentáneas.
# En la gráfica, la media móvil de 50 periodos se mantiene relativamente estable y sigue de cerca las fluctuaciones del precio de cierre, aunque con menos volatilidad. Sin embargo, durante las caídas pronunciadas en el precio, la media móvil responde con cierta demora debido a su naturaleza suavizada

# %% [markdown]
# #### Razón de la Forma de la Gráfica:
#
#
# Volatilidad: La naturaleza fluctuante del precio de cierre en la línea azul indica una alta volatilidad en las acciones de Amazon durante el periodo analizado. Este tipo de comportamiento es común en mercados financieros, especialmente en el trading de alta frecuencia.
#
#
# Diferencia entre las medias móviles y el precio de cierre: Las medias móviles reaccionan más lentamente a los cambios abruptos en el precio de cierre debido a que promedian los precios de un periodo más largo. Es por esto que, aunque el precio de cierre cae rápidamente, la media móvil de 50 periodos sigue una trayectoria más estable y con menos cambios abruptos.

# %% [markdown]
# ## EDA sobre Google

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

google_stock = yf.download('GOOGL', start='2015-01-01', end='2024-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
google_stock.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  26.629999  26.790001  26.393999  26.477501  26.412100  26480000
# 2015-01-05  26.357500  26.399500  25.887501  25.973000  25.908844  41182000
# 2015-01-06  26.025000  26.060499  25.277500  25.332001  25.269430  54456000
# 2015-01-07  25.547501  25.574499  25.182501  25.257500  25.195112  46918000
# 2015-01-08  25.075500  25.375000  24.750999  25.345501  25.282898  73054000

# %%
google_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2264 entries, 2015-01-02 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2264 non-null   float64
#  1   High       2264 non-null   float64
#  2   Low        2264 non-null   float64
#  3   Close      2264 non-null   float64
#  4   Adj Close  2264 non-null   float64
#  5   Volume     2264 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 123.8 KB

# %%
google_stock.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2264.000000  2264.000000  2264.000000  2264.000000  2264.000000
# mean     73.656450    74.445139    72.891596    73.688577    73.506563
# std      35.845056    36.275127    35.435634    35.857693    35.769122
# min      24.962000    25.014000    24.545500    24.853001    24.791613
# 25%      42.795499    43.024624    42.516251    42.834501    42.728700
# 50%      60.042002    60.487499    59.559250    60.177750    60.029110
# 75%     103.998877   105.370750   102.866253   104.379375   104.121552
# max     151.250000   151.546494   148.899002   149.838501   149.468399
#
#              Volume
# count  2.264000e+03
# mean   3.603382e+07
# std    1.730413e+07
# min    9.312000e+06
# 25%    2.574700e+07
# 50%    3.164700e+07
# 75%    4.074950e+07
# max    2.571620e+08

# %%
plt.figure(figsize=(10, 6))
plt.plot(google_stock['Adj Close'], label='Precio de Cierre Ajustado', color='blue')
plt.title('Precio de Cierre Ajustado de Google')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.legend()
plt.show()

# %% [markdown]
# Esta simple gráfica es muy útil, nos da la información de que el precio de la acción de Google tiene a ir a la alza desde hace 9 años y podemos observar cierta estacionalidad relacionada con los meses del año, aunque lo más remarcable es que las caidas tienden a ser abruptas y el crecimiento mas controlado.

# %%
# Calcular los retornos diarios
google_stock['Daily Return'] = google_stock['Adj Close'].pct_change()

plt.figure(figsize=(10, 6))
sns.histplot(google_stock['Daily Return'].dropna(), bins=50, color='purple', kde=True)
plt.title('Distribución de los Retornos Diarios de Google')
plt.xlabel('Retorno Diario')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Podemos observar que la mayoría de dias el valor de retorno diario de la acción está en torno a cero, lo que nos quiere decir que esta acción tiene un precio bastante estable, pero existen los valores mas extremos que nos indican que hay días en los que la acción cambia de precio mas bruscamente.

# %%
# vemos los valores mas bajos de retornos diarios
top_negative_returns = google_stock['Daily Return'].nsmallest(5)
print("\nValores más bajos (negativos):")
print(top_negative_returns)
# Out:
# Valores más bajos (negativos):
# Date
# 2020-03-16   -0.116342
# 2023-10-25   -0.095094
# 2022-10-26   -0.091405
# 2020-03-12   -0.082046
# 2023-02-08   -0.076830
# Name: Daily Return, dtype: float64

# %%
google_stock['Month'] = google_stock.index.month

plt.figure(figsize=(12, 6))
sns.boxplot(x='Month', y='Adj Close', data=google_stock)
plt.title('Distribución del Precio de Cierre Ajustado por Mes')
plt.xlabel('Mes')
plt.ylabel('Precio de Cierre Ajustado')
plt.show()

# %% [markdown]
# Acá podemos ver que los precios tienden a ser un poco más altos en verano y a bajar en el final e inicio del año. Pero hay outliers altos en todos los meses, exceptuando mayo, junio y julio.

# %% [markdown]
# ## Model Experiments

# %% [markdown]
# En esta carpeta podemos observar los experimentos de modelos creados para resolver el precio de cierre de una acción basandonos en las columnas de precio de apertura, fecha, High y Low historicos.

# %% [markdown]
# Hicimos experimentos con XGboost y Random Forest, siendo este último el que nos proporcionó mejores métricas en los resultados.

# %% [markdown]
# Donde en Amazon model aplicamos el xgboost, en el apple analysis vimos el comportamiento de una serie temporal de la acción con una regresión y se trató hacer un modelo Arima y sirvió para un buen análisis.
# Siendo así que la acción de google fue la única donde aplicamos dos modelos, el random forest y xgboost donde en el xgboost usamos todas las columnas del df menos la variable a predecir que fue 'Close'

# %% [markdown]
# También tenemos un notebook sobre cálculo de ganancias donde lo que aplicamos es usar nuestro mejor modelo con prefect y sacar los inputs de cuánto dinero es el que quiere invertir el usuario y los días que quiere invertir y aplicamos también un modelo Naive paso por paso para hacer el cálculo de la proporción del precio estimado respecto al precio inicial

# %% [markdown]
# ## Training Pipeline

# %% [markdown]
# En esta carpeta podemos observar los archivos con el propósito de automatizar el proceso de entrenamiento de modelos. Usamos las herramientas de MLflow y Dagshub para registrar y gestionar los experimentos, esto con el propósito de facilitar el uso de estos.

# %% [markdown]
# Dividimos el Training Pipeline en la siguiente estructura:
#
# + Lectura de datos:
#
# Leemos los datos descargados de Yahoo Finance.
#
# + Generar features:
#
# Dividimos los datos en variables predictoras (X) y la variable objetivo (Close).
# Usamos train_test_split para separar el conjunto de entrenamiento y validación.
#
# + Tuning de hyperparámetros:
#
# Optimizamos los parámetros del modelo Random Forest utilizando hyperopt y registra los experimentos en MLflow.
#
# + Entrenamiento del mejor modelo
#
# Entrenamos un modelo Random Forest con los mejores hiperparámetros encontrados.
#
# + Registro del modelo:
#
# Usamos la API de MLflow para registrar el mejor modelo entrenado y asignarle un alias "Champion" para referenciarlo fácilmente.
#
# + main_flow:
#
# Coordinamos con Prefect y ejecutamos.

# %% [markdown]
# ## Source
#
# + App(interfaz/UI):
#
# Iniciamos una clase App de flask y creamos 2 blueprints(objetos suscritos a la clase) para las acciones del usuario y las acciones de la autorización de loggeo. Tambien creamos todos los templates correspondientes con html, css y htmx.
#
#
# + Orchestrator:
#
#
# Creamos una segunda clase App de flask en este caso para conectar los puertos de la interfaz con el api de ML_Models. Es todo lo que hace esta sección.
#
#
#
# + ML_models:
#
#
# En otra API App de flask esta cargado el modelo a traves de dagshub. Para recibir los datos cargados desde el orquestador, procesarlos y devolverlos hacia la UI.
#
#
#
# + dockerfiles:
#
#
# En estas imagenes esta cargado el ambiente para cada una de las APIs descritas anteriormente. Tambien especifica el puerto que utiliza cada una de ellas para sus comunicaciones.
#
#
#
# + docker-compose:
#
#
# Aqui se configura el conjunto de procesos para correr todo el servicio incluye la base de datos(mongo) y la configuracion de los puertos con las imagenes.

# %% [markdown]
# ## CONCLUSIONES

# %% [markdown]
# Este proyecto nos permitió consolidar los conocimientos adquiridos a lo largo del semestre y poner en práctica lo que conocemos de materias anteriores.
# Aprendimos a organizar la estructura de un proyecto
#  A orquestar el pipeline con prefect
# Hacer tracking y registro de modelos con MLflow
# Conectarlo con una aplicación amigable con el usuario
# Utilizar docker y docker-compose
# Configurar una instancia en AWS
# Trabajar en equipo e investigar en diversos sitios
#
#  Esperemos este sea un gran paso en nuestra carrera como Data Scientists y nos permita trabajar en proyectos mas importantes en un futuro.

# %% [markdown]
# También este proyecto nos da confianza en seguir adelante y a darnos una realidad sobre lo que puede ser un poco la vida laboral afuera de la escuela y estamos muy agradecidos con el profe por estas prácticas y las clases que fueron de mucha ayuda y muy buenas. Creemos también nos dimos cuenta de lo importante que es trabajar en equipo para estas situaciones, la organización y la implemetación del trabajo de cada uno y las retroalimentciones, muchas gracias por todo.

# %% [markdown]
# ## REFERENCIAS

# %% [markdown]
#  https://github.com/zapatacc/ProyCienDatos2024-2
#
# Documentacion de MLflow:  https://mlflow.org/docs/latest/index.html
#
# Documentación oficial de yfinance:
# https://pypi.org/project/yfinance/
